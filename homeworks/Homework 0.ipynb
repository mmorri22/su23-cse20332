# %% [markdown]
# # Homework 0 - Coding Environment Setup

# %% [markdown]
# ><b>Qualitative Feedback</b>: The purpose of this workflow is to provide you with better <i>feedback</i>. Instead of simply determining if your work is correct, the instructor will attempt to provide you with more qualitative feedback such as whether or not you used good programming practices or if your code could be improved or organized better. The hope is that this will help you grow as programmers and develop some strong habits :).

# %% [markdown]
# ## Section 1 - Tabby, OpenSSH, and VPN Introduction

# %% [markdown]
# ### 1.1 - What is an SSH, and what are Tabby and OpenSSH?
# The <b>Secure Shell (SSH)</b> is a communication protocol between a <b>client</b> (you) and a <b>Server</b> (ND Machines). The general overview is shown below. The crucial knowledge you should take away is that SSH permits you to run commands on your laptop, and the program is executed on another machine.
#
# <a href = "https://tabby.sh/">Tabby</a> is a customizable cross-platform terminal app for local shells, serial, SSH and Telnet connections. This program is open source and works well across Windows, MacBook, and Linux operating systems. Tabby is useful for SFTP and Zmodem file transfers, X11, and port forwarding.
#
# <ul>
# <li>One benefit of Tabby as opposed to programs liked PuTTy and XTerm is that you can use one program to <b>run several tasks</b>. Additionally, for students who prefer using multiple Vim tabs as opposed to File Transfer Programs (like the FileZilla program I will ask you to install later), you are welcome to use this approach.</li>
#     <li>Another benefit of Tabby is that there are many <a href = "https://tabby.sh/about/features">features</a> which allow you to change the color and size of the Terminal to make observation <b>easier on your eyes</b>. There are also several plugins you can install and play with to enhance your programming experience.</li>
# </ul>

# %% [markdown]
# ### 1.2 - Installing VPN to run SSH off-campus
#
# This section is to help students install a Virtual Private Network (VPN) Client on their machine. Students who are off-campus can code while away from campus if they use the VPN.
#
# > <b>Note</b>: Please ensure this step works, even if you live on campus. Part of the course resiliency plan is that students will be able to quickly access the ND Machines through the Virtual Private Network in the event you need to head back home. If you are having issues with the VPN, please do not hesitate to contact me, or OIT in steps when I say you should contact them.
#
# To begin VPN installation:
# 1. Go to https://vpnaccess.nd.edu/go (Note: The /go is essential for ND/SMC students to gain VPN access) and log in with your Notre Dame NetId (For example, my Notre Dame netID is <code>mmorri22</code>). You must be logged in for any of the next AnyConnect VPN steps to work.
#
# > <b>Note 1</b>: If your log in information does not work, contact oit@nd.edu immediately in order to get your log in resolved. You will not be able to run any code or submit Programming Challenges from off-campus unless you complete this task.
#
# > <b>Note</b>: Contact oit@nd.edu if you get any error messages indicating you do not have access. The most common message is the 403 message shown below. This issue is common, and is typically resolved in two days once we bring it to OIT's attention.
#
# ![VPN Error](https://github.com/mmorri22/su23-cse20332/blob/main/homeworks/homework0/VPN%20403.png?raw=true)
#
# 2. Next, go to the AnyConnect Client Page, and then select the AnyConnect VPN Client as appropriate for your Operating System, You may also choose the appropriate version from the list below. If there is a pop-up, the prompt is asking for your Notre Dame NetID and password. (All download links most recently verified on 6/11/2022):
#
# >Note: A valid Notre Dame netID is required to access these download links:<br>
# ><ul>
#     ><li>AnyConnect v4.10 for <b>Windows</b> - [ <a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-win-4.10.00093.msi">Click Here to Download</a> ]</li>
# ><li>Older Version if v4.10 does not work for Windows: AnyConnect v4.7 for Windows - [<a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-win-4.7.04056.exe"> Click Here to Download</a> ]</li>
# ><li>AnyConnect v4.10 for <b>macOS</b> (Compatible w/ macOS 11 Big Sur) - [ <a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-macos-4.10.zip">Click Here to Download</a> ] [ <a href = "https://nd.service-now.com/kb_view_login.do?sysparm_article=KB0021712">UI Change Documentation</a>]</li>
# ><li>Older Version for macOS if v4.10 does not work: AnyConnect v4.8 for macOS 10.15 - Catalina - [ <a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-macos-4.8.00175.dmg">Click Here to Download</a> ]  </li>
# ><li>AnyConnect v4.7 for macOS older than Catalina, ie Mojave and earlier - [ <a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-macos-4.7.dmg">Click Here to Download</a> ]</li>
#     ><li>AnyConnect v4.10 for <b>Linux</b> - [ <a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-linux64-4.10.00093.sh.zip">Click Here to Download</a> ] [ <a href = "https://nd.service-now.com/nd_portal?id=kb_article&sys_id=dfe2b9691b6e04d0892b77761a4bcbee">Configuration Information</a> ]</li>
# ><li>Older of Linux version if v4.10 does not work: AnyConnect v4.7 for Linux - [ <a href = "https://www3.nd.edu/~ndoit/software/common/vpn/anyconnect-linux64-4.7.04056.sh.zip">Click Here to Download</a> ] </li>
#     ><li>AnyConnect v4.5 for Windows Users using a <b>Secure Key</b> (YubiKey) - [<a href = "https://www3.nd.edu/~ndoit/software/common/vpn/AnyConnect4.5.exe"> Click Here to Download</a> ]</li>
# ></ul>
#
# 3. Once you have the AnyConnect client installed, open the program. Type vpnaccess.nd.edu/go and click Connect, as shown below
#
# <b>Visualize It!</b> The video below shows an example of a successful log on with AnyConnect. I install the Client, and then run it to establish a connection to the Notre Dame campus server. Please note that, as a faculty, I do not use /go in my log on, which I explain in the video.
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=FkgAMZjzG7M" target="_blank">
#  <img src="http://img.youtube.com/vi/FkgAMZjzG7M/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>
#
# #### Next steps...
# <ul>
#     <li>If you are on a Windows machine, go to <b>Section 1.3 - Installing Tabby on a Windows Machine</b></li>
#     <li>If you are on a Apple MacBook, go to <b>Section 1.4 - Installing Tabby on a MacOS</b></li>
# <li>If you are using an Ubuntu Operating System, go to <b>Section 1.5 - Installing OpenSSH on an Ubuntu OS</b></li>
# </ul>

# %% [markdown]
# ### 1.3 - Installing Tabby on a Windows Machine
#
# This section is to assist in helping students with PCs and Windows laptops install the Tabby SSH client on their machine, and be able to log into the Notre Dame servers.
#
# 1 - Go to the Tabby download page: https://github.com/Eugeny/tabby/releases/tag/v1.0.169
#
# Next, scrolls down past the "Assets" and select the appropriate "setup.exe" file
# For the Summer 2023 semester, the most up-to-date version is <a href = "https://github.com/Eugeny/tabby/releases/download/v1.0.169/tabby-1.0.169-setup.exe">tabby-1.0.169-setup.exe</a>.
#
# Run the setup.exe file and follow the prompts.
#
# > Note: There is a video after Step 3 where I show how to perform Steps 2 and 3.
#
# 2 - Once installed, type "Tabby Terminal" in the Windows search bar. This command will bring up the Tabby Terminal app for you to run.
#
# ![Tabby Terminal](https://github.com/mmorri22/su23-cse20332/blob/main/homeworks/homework0/Tabby%20Terminal.png?raw=true)
#
# 3 - In the first tab, you should enter the command: <code>ssh -Y [Your_NetID]@student00.cse.nd.edu</code>
#
# > Example: my email is <code>matt.morrison@nd.edu</code>, but my NetID is <code>mmorri22</code>, so I need to use <code>ssh -Y mmorri22@student00.cse.nd.edu</code> to log into the servers.
#
# <ul>
#     <li>The <code>-Y</code> is included to treat the Notre Dame machines as a <b>trusted client</b>.</li>
#     <li>You can use any of the <code>student00 - student12</code> servers in this course.</li>
# </ul>
#
# > <b>Optional Reading</b>: <code>student00.cse.nd.edu</code> through <code>student12.cse.nd.edu</code> are Mirror servers, meaning they are different machines, but host the same content: https://en.wikipedia.org/wiki/Mirror_site
# <p></p>
# Once completed, you will now have access to your Unix environment.
#
# <b>Visualize It!</b>The video below shows steps 2 and 3, and what you should expect.
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=c2ZcatvsJ6k" target="_blank">
#  <img src="http://img.youtube.com/vi/c2ZcatvsJ6k/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>
#
# <b>Next Steps</b>: Go to Section 2 - FileZilla Installation

# %% [markdown]
# ### 1.4 - Installing Tabby on a Mac OS
#
# > Note to Mac Users: Tools like XQuartz have caused Mac users significant headaches in Intro to C/C++, Data Structures, and Systems Programming over the years. At this stage in your academic and professional career, Tabby "gets the job done".
# >
# > Also, there are some unresolved issues with Linux and the new Big Sur Operating System. We will update these directions as we work with you to resolve them.
#
# This section is to assist in helping students with <b>Apple laptops and macOS operating systems</b> install the X11 client on their machine, and be able to log into the Notre Dame servers:<p></p>
#
# 1 - You will need to know which type of architecture you have. First, you will need to access the <b>Activity Monitor</b>
# <ul>
#     <li>Easiest approach: Perform a spotlight search (Command-Spacebar) and type "Activity Monitor"</li>
#     <li>Otherwise, it is located in <code>/Applications/Utilities</code>.</li>
# </ul>
# <p></p>
# Once inside System Profiler, navigate the tabs on the left and open the <b>Software</b> tab, and select <b>Applications</b>.
#
# Now you will have a list of all apps installed on your Mac. Expand the window, and in the far right column you’ll see the <b>architecture type</b>. Make a note of this architecture in order to complete the next step.
# <ul>
#     <li>You will most likely have an x86_64 architecture.</li>
#     <li>Otherwise, you will have an ARM architecture.</li>
# </ul>
#
#
# 2 - Go to the Tabby download page: https://github.com/Eugeny/tabby/releases/tag/v1.0.169
#
# <ul>
#     <li>Next, scroll down past the "Assets" and select the appropriate <code>pkg</code> file</li>
#     <li>Most of you will have an x86_64 architecture, so you will want to download tabby-1.0.169-macos-x86_64.pkg</li>
#     <li>If you have an ARM architecture, you will want to download tabby-1.0.169-macos-arm64.pkg</li>
# </ul>
# <p></p>
#
# 3 - In the first tab, you should enter the command: <code>ssh -Y [Your_NetID]@student00.cse.nd.edu</code>
#
# > Example: my email is <code>matt.morrison@nd.edu</code>, but my NetID is <code>mmorri22</code>, so I need to use <code>ssh -Y mmorri22@student00.cse.nd.edu</code> to log into the servers.
#
# <ul>
#     <li>The <code>-Y</code> is included to treat the Notre Dame machines as a <b>trusted client</b>.</li>
#     <li>You can use any of the <code>student00 - student12</code> servers in this course.</li>
# </ul>
#
# > <b>Optional Reading</b>: <code>student00.cse.nd.edu</code> through <code>student12.cse.nd.edu</code> are Mirror servers, meaning they are different machines, but host the same content: https://en.wikipedia.org/wiki/Mirror_site
# <p></p>
# Once completed, you will now have access to your Unix environment.
#
# <b>Next Steps</b>: Go to Section 2 - FileZilla Installation

# %% [markdown]
# ### 1.5 - Installing OpenSSH on an Ubuntu OS
#
# 1 - Install <b>OpenSSH</b> on Ubuntu to be able to access the ND server
# <ul>
#     <li>Open the terminal application for Ubuntu desktop</li>
#     <li>Type the following command: <code>sudo apt-get install openssh-server</code></li>
#     <b>Note</b>: You will need root access, which you should have on your own laptop.
#     <li>Enable the ssh service by typing the following command: <code>sudo systemctl enable ssh</code></li>
#     <li>Start the ssh service by typing the following command: <code>sudo systemctl start ssh</code></li>
# </ul>
#
# 2- From the Terminal, enter the command: <code>ssh -Y [Your_NetID]@student00.cse.nd.edu</code>
#
# > Example: my email is <code>matt.morrison@nd.edu</code>, but my NetID is <code>mmorri22</code>, so I need to use <code>ssh -Y mmorri22@student00.cse.nd.edu</code> to log into the servers.
#
# <ul>
#     <li>The <code>-Y</code> is included to treat the Notre Dame machines as a <b>trusted client</b>.</li>
#     <li>You can use any of the <code>student00 - student12</code> servers in this course.</li>
# </ul>
#
# > <b>Optional Reading</b>: <code>student00.cse.nd.edu</code> through <code>student12.cse.nd.edu</code> are Mirror servers, meaning they are different machines, but host the same content: https://en.wikipedia.org/wiki/Mirror_site
# <p></p>
# Once completed, you will now have access to your Unix environment.
#
# <b>Next Steps</b>: Go to Section 2 - FileZilla Installation

# %% [markdown]
# ### 1.6 - If you are unable to successfully get onto the ND Machine...
#
# Contact Professor Morrison or a Teaching Assistant as soon as you have tried all the steps above on your specific laptop if you are unable to log into the Notre Dame machines. The most common reason for students in the 20232/60732 course being unable to log into the machines is an enrollment issue, which can be remedied promptly.

# %% [markdown]
# ## 2 - FileZilla Installation
#
# FileZilla is a client that allows you to transfer files between your machine and the ND server make edits on your local machine.
# <ul>
#     <li>Easier to make certain edits that VIM</li>
#     <li>Can make a backup copy on your local machine</li>
#     <li>Don’t have to worry unless you make an error</li>
# </ul>
#
# This program will make it much easier and efficient for you to be able to perform larger in-class coding assignments, as opposed to using Vim. Vim is a wonderful tool, and is particularly effective for courses like Introduction to Computing.
#
# As projects get larger, many students find trying to keep track of several files through Vim to be prohibitively difficult in later projects. FileZilla is provided to you as an option to manage your projects more effectively.
#
# Furthermore, you can make an additional backup copy on your local machine in the event some you lose some of your code.
# <ul>
# <li>We will use Vim regularly, as it will be helpful for you in other courses, such as the Logic Design course, as well as in your career.</li>
# <li>You are not required to use FileZilla. This program is an option for you to use to improve your programming experience.</li>
# </ul>

# %% [markdown]
# ### 2.1 - Installation on Windows or MacBook
#
# 1 - Go to the following page to download executable for FileZilla that correlates with your OS:
# <ul>
# <li><a href = "https://filezilla-project.org/download.php?type=client">FileZilla Windows 64-bit</a></li>
# <li><a href = "https://filezilla-project.org/download.php?platform=win32">FileZilla Windows 32-bit</a></li>
# <li><a href = "https://filezilla-project.org/download.php?platform=osx">FileZilla Mac OS X</a></li>
# </ul>
#
# 2 - Follow the installation instructions
#
# > Note: There is <i>no need</i> to install any other programs that FileZilla may prompt you to install. Sometimes, during the installation process, the installer will ask if you want to install a different program. You may decline all those offers and still be able to install the program for free.
#
# <b>Next step</b> - Go to Section 2.3 - Connecting FileZilla to the ND Machines.

# %% [markdown]
# ### 2.2 - Installation on Ubuntu
#
# 1 - Open the terminal application for Ubuntu desktop
#
# 2 - Run the command: <code>sudo apt update</code>
#
# 3 - Run the command: <code>sudo apt install filezilla</code>
#
# <b>Next step</b> - Go to Section 2.3 - Connecting FileZilla to the ND Machines.

# %% [markdown]
# ### 2.3 - Connecting FileZilla to the ND Machines
#
# 1 - Open the FileZilla tool on your machine. Enter <code>student00.cse.nd.edu</code> as the Host, your NetID and password, and Port <code>22</code> as shown below:
# > Like Tabby or OpenSSH, you can use <code>student00</code> through <code>student12</code> this semester.
#
# 2 - Once you successfully open the connection, you will see a set of files on the right hand side. It will look similar, but not identical, to what is visible when I open my account. This is because I have a different set of files and folder than you. Later, we will discuss the process of transferring files between your laptop and the Notre Dame machines.
#
# <b>Visualize It!</b> - This video shows how to log into the ND Machines using the FileZilla FTP client. In this video, I briefly show a file transfer, where I run the FileZilla on <code>student00</code>, but show the file on <code>student06</code> through Tabby in order to show the benefits of mirror servers.
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=hvZMQdAVKxA" target="_blank">
#  <img src="http://img.youtube.com/vi/hvZMQdAVKxA/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>
#
# <b>Next Steps</b> - Go to Section 3 - Atom Installation

# %% [markdown]
# ## 3 - Pulsar Installation
#
# <a href = "https://pulsar-edit.dev/">Pulsar</a> is a text editor developed by GitHub which allows you to be able to open your files through a File Transfer client (like FileZilla), edit them on your local machine, and then have the edits reflected on the Notre Dame machines. One of the benefits of Pulsar is that it allows you to create your own GitHub account and work with git. As you advance in your computing proficiency, this tool will backing up your future coursework much easier, as well as prepare you for industry. In my experience, students greatly prefer Pulsar to other tools like Notepad++.
#
# For <b>Windows</b> users, go to <b>3.1 - Install Pulsar for Windows</b>
#
# For <b>macOS</b> users, go to <b>3.2 - Install Pulsar for Mac</b>
#
# For <b>Ubuntu</b> users, go to <b>3.3 - Install Ubuntu for Mac</b>

# %% [markdown]
# ### 3.1 - Install Pulsar for Windows
#
# 1 - Download the <a href = "https://download.pulsar-edit.dev/?os=windows&type=windows_setup">Pulsar setup executable</a><p></p>
#
# 2 - Follow the directions on the installer.<p></p>
#
# 3 - Go into your FileZilla program. Go to Edit -> Settings. On the left hand side, select "File editing."<p></p>
#
# 4 - Next, under "Default Editor", select "Use custom editor" and then select Browse.<p></p>
#
# 5 - Pulsar will be under the <code>C:\Program Files\Pulsar\Pulsar.exe</code>. Select that file.<p></p>
#
# 6 - Back on FileZilla, select "Always use Default Editor" and select OK.<p></p>
#
# <b>Visualize It!</b> - In this video, I show the process of setting Pulsar as the custom editor and making a change using Pulsar to the code on the student machines.
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=IpVUU7xYXJ4" target="_blank">
#  <img src="http://img.youtube.com/vi/IpVUU7xYXJ4/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>
#
# <b>Next Steps:</b> Go to Section 4 - Introduction to the Linux Command Line

# %% [markdown]
# ### 3.2 - Install Pulsar for MacOs
#
# 1 - Download the correct <code>dmg</code> file from the Pulsar page:
# <ul>
#     <li><a href = "https://download.pulsar-edit.dev/?os=silicon_mac&type=mac_dmg">Silicon - For Apple Silicon (M1/M2) macs</a> (This will be most of you)</li>
#     <li><a href = "https://download.pulsar-edit.dev/?os=intel_mac&type=mac_dmg">Intel - For Intel macs</a></li>
# </ul>
# <p></p>
#
# 2 - Follow the directions on the installer.<p></p>
#
# 3 - Go into your FileZilla program. Go to Edit -> Settings. On the left hand side, select "File editing"<p></p>
#
# 4 - Next, under "Default Editor", select "Use custom editor" and then select Browse.<p></p>
#
# 5 - Go to <code>Applications</code> and select <code>Pulsar</code>
#
# 6 - Back on FileZilla, select "Always use Default Editor" and select OK.
#
# <b>Visualize It!</b> - In this video, I show the process of setting Pulsar as the custom editor and
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=IpVUU7xYXJ4" target="_blank">
#  <img src="http://img.youtube.com/vi/IpVUU7xYXJ4/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>
#
# <b>Next Steps:</b> Go to Section 4 - Introduction to the Linux Command Line

# %% [markdown]
# ### 3.3 - Install Pulsar for Ubuntu
#
# 1 - Download the <a href = "https://download.pulsar-edit.dev/?os=linux&type=linux_deb">Pulsar setup executable <code>deb</code> file</a><p></p>
#
# 2 - Navigate to Downloads. Right-click the deb file and choose Open with Another Application.
#
# 3 - Select Software Install from the program list. ...
#
# 4 - Click on the Install button to proceed. Follow the directions on the installer.
#
# 3 - Go into your FileZilla program. Go to Edit -> Settings. On the left hand side, select "File editing."<p></p>
#
# 4 - Next, under "Default Editor", select "Use custom editor" and then select Browse.<p></p>
#
# 5 - Browse to <code>/usr/bin/pulsar</code> and select the executable. Select that file.<p></p>
#
# 6 - Back on FileZilla, select "Always use Default Editor" and select OK.<p></p>
#
# <b>Visualize It!</b> - In this video, I show the process of setting Pulsar as the custom editor and making a change using Pulsar to the code on the student machines.
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=IpVUU7xYXJ4" target="_blank">
#  <img src="http://img.youtube.com/vi/IpVUU7xYXJ4/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>
#
# <b>Next Steps:</b> Go to Section 4 - Introduction to the Linux Command Line

# %% [markdown]
# ## 4 - Introduction to the Linux Command Line
#
# ### 4.1 - Command Line Compilation
#
# 1 - Go to your Tabby terminal, and perform the following basic Unix commands
#
# Where am I?:
# <ul>
#     <li><code>ls</code> (ls stands for list)</li>
#     <li><code>pwd</code> (pwd stands for Present Working Directory)</li>
# </ul>
#
# 2 - Create a directory to work in. First, we will go into the Dropbox directory where you will submit your code
#
# <code>cd esc-courses</code>
#
# Next, go to the Dropbox with the course folder:
#
# <code>cd su23-cse-20232.01</code>
#
# At this point, you will make a directory for you to practice your code. The command <code>mkdir</code> stands for <b>Make Directory</b>. Then you will change directory (using the command <code>cd</code>) into that folder.
#
# The dropbox folder is available to Professor Morrison and the Teaching Assistants. In order to get more effective help during office hours, it is strongly recommended that you put all course code in your dropbox.
#
# <code>cd dropbox</code>
#
# > <b>Note</b>: The video below the next few steps shows the process of making a directory, obtaining a file from online, and performing these steps in Vim. Refer to the video below if you are having issues with completing these steps.
#
# <code>mkdir code-env</code>
#
# <code>ls</code>
#
# >You will see the <code>code-env</code> folder
#
# <code>cd code-env</code>
#
# ><code>cd</code> stands for <b>Change Directory</b>, so you are changing directories to the <code>code-env</code> folder you created folder
#
# <code>pwd</code>
#
# > <code>pwd</code> stands for <b>Present Working Directory</b>.
# > Make a note of the output. It will likely be the following:
# > <code>/escnfs/home/[YourNetID]/esc-courses/sp23-cse-20232.01/dropbox/code-env</code>
#
# Next, you will learn how to obtain a file from online.
#
# <code>wget</code> is a command that will make a copy of a public file in your local directory. In this case, you are obtaining a <code>hello.c</code> file.
#
# <code>wget https://raw.githubusercontent.com/mmorri22/su23-cse20332/main/homeworks/homework0/hello.c</code>
#
# >Note: You need to use <code>raw.githubusercontent.com</code> version of the file when running <code>wget</code> from GitHub, or else you will download the HTML that used to render hello.c at the GitHub page
#
# <code>ls</code>   (You should now be able to see hello.c)
#
# View the file in vim
#
# <code>vim hello.c</code>
#
# Make a change in the file. Type the letter <code>i</code>. This will allow you to insert elements into the file.
#
# If you did this successfully, you will see <code>--INSERT--</code> at the bottom.
#
# Make the following changes to the file
# <ul>
# <li>From my name to your name</li>
# <li>From my email to your email</li>
# <li>Change the Hello, World to a message of your choosing.</li>
# <li>Save the Changes</li>
# </ul>
#
# To save the changes, perform the following:
# <ul>
#     <li>Press <code>Esc</code> (nothing will appear to happen)</li>
# <li>Next, press <code>Shift</code> and <code>:</code> simultaneously</li>
# <li>At the bottom of the screen, you will see a <code>:</code> and a <font color = "green">green box</font> appear, which means you can now enter vim commands.</li>
# <li>To write and quit, type <code>wq!</code> (including the exclamation point). This will close the file.</li>
# <li>Compile and run the program</li>
# </ul>
#
# You can run a program from the command line. Carefully read the comments below the command so you type the flags properly. Additionally, there is a video that takes you through the process and replicates some common errors.
#
# <code>gcc -g -O2 -std=c11 -Wall -Wextra -Wconversion -Wshadow -lm -Werror hello.c -o hello</code>
#
# <ul>
# <li><code>gcc</code> is the compiler on the Notre Dame machines for C</li>
# <li><code>-g</code> allows you to be able to store information for GDB, a debugging tool we will explore later in this course</li>
# <li><code>-O2</code> compiles the code to run optimally on Linux machines</li>
# </ul>
#
# > Common student mistake: The first character is capital letter <code>O</code>, not lowercase <code>o</code>, nor the number <code>0</code>
#
# <ul>
# <li><code>-std=c11</code> compiles the 2011 C Standard</li>
# <li><code>-Wall</code> means flag all warnings for C prior to the 1999 standard</li>
# <li><code>-Wextra</code> means all warnings for C after the 1999 standard</li>
# <li><code>-Wconversion</code> ensures proper conversion of data between variables</li>
# <li><code>-Wshadow</code> ensures you do not name multiple variables with the same name in the same scope (prevents variable shadowing)</li>
# <li><code>-lm</code> stands for "Link Math" and allows you to use C libraries to perform mathematical operations</li>
# </ul>
#
# > Common mistake: The first character is lowercase letter l, not uppercase letter L, nor the number 1
# -Werror means we treat all warnings as errors-o means convert the hello.c source file to an executable called hello.
# > Common mistake: The character is lowercase o, not uppercase letter O, nor the number 0
#
# To run an executable in Linux on the Notre Dame machine, you need to start with <code>./</code> in front
#
# <code>./hello</code>
#
# Listing the size and creation time: You can view the time a file most recently updated and the size of the file by performing the following command:
#
# <code>ls -l</code>
#
# Note: This command is <code>ls -l</code> (letter <code>l</code>, not the number <code>1</code>)
#
# You can observe that the green file (<code>hello</code>) is much larger than the source file (<code>hello.c</code>). Executables and object files are <i>significantly</i> larger than code files. This is the reason we create Makefiles, so we can remove executables, and then create them on a different machine while only transporting the source file.
#
# Let's remove <code>hello</code> by performing the following command:
#
# > <b><font color="red">Important note</font></b>: Before you type the next command, be absolutely sure there is not a space between the <code>*</code> and the <code>.</code>, because if you do, you are attempting to delete all the files on the Notre Dame machines. Now, there are protections so you can't delete everyone else's code, but the command will attempt to delete all your code. If you accidentally delete all your code, there is no guarantee we will be able to recover your previous work. This is an important thing to bear in mind throughout this semester as you build Makefiles
#
# <code>rm *.o hello</code>
#
# <code>ls -l</code>
#
# You can now see that the hello executable is gone. After successfully running these commands, your output should look similar to this.To clean up the commands, run the following command:
#
# <code>clear</code>
#
# <b>Visualize It!</b> - I perform the steps from <code>wget</code> to completion of this task as an example to demonstrate each step.
# <center><a href="http://www.youtube.com/watch?feature=player_embedded&v=rarkDcBuqqA" target="_blank">
#  <img src="http://img.youtube.com/vi/rarkDcBuqqA/mqdefault.jpg" target="_blank" width="240" height="180" border="10" />
# </a></center><p></p>

# %% [markdown]
# ### 4.2 - Using a Makefile
#
# <b>Makefiles</b> allow us to compile larger programs when using several libraries that we designed. Imagine having to type 15 gcc command lines properly <i>every time</i>! That would get exhausting and frustrating rather quickly. We will learn about Makefiles in more detail later in the course, but for now, the objective is for you to get a basic understanding of how they work.
#
# 1 - To run the Makefile, run the following three commands:
#
# <code>wget https://raw.githubusercontent.com/mmorri22/su23-cse20332/main/homeworks/homework0/nothing.c</code>
#
# <code>wget https://raw.githubusercontent.com/mmorri22/su23-cse20332/main/homeworks/homework0/specifiers.c</code>
#
# <code>wget https://raw.githubusercontent.com/mmorri22/su23-cse20332/main/homeworks/homework0/Makefile</code>
#
# <code>ls -l</code>
#
# This command should now show the four files, <code>hello.c</code>, <code>nothing.c</code>, <code>specifiers.c</code>, and <code>Makefile</code>.
#
# To run commands using the Makefile, perform the following commands:
#
# <code>make nothing</code>
#
# <code>make hello</code>
#
# <code>make specifiers</code>
#
# <code>./nothing</code>
#
# <code>./hello</code>
#
# <code>./specifiers/code>
#
# <code>ls -l</code>
#
# The result is that <code>./nothing</code> should have printed nothing, <code>./hello</code> should have printed your modified code, <code>./specifiers</code> should print out decimal and hexadecimal values of two numbers, and <code>ls</code> should show the following files:
#
# ><code>-bash-4.2$ ls</code><br>
# ><code>hello    hello.o   nothing    nothing.o   specifiers.c</code><br>
# ><code>hello.c  Makefile  nothing.c  specifiers  specifiers.o</code>
# <p></p>
# You can observe that the object files and executables are much larger than the source files. Therefore, we can clean everything up by running the following
#
# <code>make clean</code>
#
# <code>ls -l</code>
#
# You can now see that the object files and executables are now gone.
#
# #### Changing the names of files
#
# In this next step, you will change the names of files using the mv command.
#
# <code>mv hello.c modHello.c</code>
#
# <code>mv specifiers.c modPrint.c</code>
#
# <code>ls -l</code>
#
# You will now see that <code>hello.c</code> and <code>specifiers.c</code> are replaced with <code>modHello.c</code> and <code>modPrint.c</code>
#
# #### Changing the Makefile
#
# Now you will make your first modifications to the Makefile. In this step, you will gain familiarity with FileZilla.
#
# In the FileZilla program, find the <code>esc-courses</code> folder and click on it. (This step assumes you are logged in using FileZilla)
# <ul>
# <li>Next, select <code>su23-cse-20232.01</code></li>
# <li>Next, select the <code>dropbox<c/ode> folder.</li>
# <li>You should now be able to see your <code>code-env</code> folder.</li>
# <li>Go into that folder.
# <li>Right click on <code>Makefile</code> and select <code>View/Edit</code>. This will open a copy of the Makefile on your local machine using Pulsar.</li>
# <li>You will now update the Makefile commands using Pulsar. The example for <code>hello</code> is shown below.</li>
# </ul>
#
# Before:<br>
# <code># Compilation for the Hello, World</code><br>
# <code># Command: make hello</code><br>
# <code>hello: hello.o</code><br>
# <code>   $(CC) $(CFLAGS) -o hello hello.o</code><br>
# <code>hello.o: hello.c</code><br>
# <code>   $(CC) $(CFLAGS) -c hello.c</code><br>
#
# After:<br>
# <code># Modified Hello for Lab 1</code><br>
# <code># Command: make modHello</code><br>
# <code>modHello: modHello.o</code><br>
# <code>    $(CC) $(CFLAGS) -o modHello modHello.o</code><br>
# <code>modHello.o: modHello.c</code><br>
# <code>   $(CC) $(CFLAGS) -c modHello.c</code><br>
#
# Perform the same task for changing <code>specifiers.c</code> to <code>modPrint.c</code>
#
# Also, modify the make all command and make clean commands so that <code>modHello</code> replaces <code>hello</code> and <code>modPrint</code> replaces <code>specifiers</code>.
#
# > Note: In a Makefile, you will learn that the tab before <code>$(CC)</code> is essential. If you try to replace those with spaces, the Makefile will not compile.
#
# In order to save the file back to the Notre Dame machine, you will Press Save on Pulsar.
#
# Go back to FileZilla. You will see a pop-up similar to the one below. Select Yes.
# This action will update on the local machine.
#
# #### Testing whether your updates worked
#
# If you can run the command <code>make all</code> and then <code>make clean</code> as shown in the figure below, you have successfully completed the lab assignment. The <code>ls -l</code> shows the last day modified, so this is how we will know you completed the assignment on time.
#
# <b><font color = "red">Successful running of <code>make all</code> and <code>make clean</code>will constitute a full credit submission.
